# %% [markdown]
# username: himanshu_kaushik
# password: u15iR1kuvtz9HvwF

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://himanshu_db_user:u15iR1kuvtz9HvwF@cluster1.tlkxih6.mongodb.net/?appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#load the data set
import pandas as pd
df = pd.read_csv("E:/Projects/Customer-Categorizer/notebooks/data/clustered_data.csv")

# %%
df.head()
# Out:
#    Age  Education  Marital Status  Parental Status  Children   Income  \
# 0   68          2               0                0         0  58138.0
# 1   71          2               0                1         2  46344.0
# 2   60          2               1                0         0  71613.0
# 3   41          2               1                1         1  26646.0
# 4   44          4               1                1         1  58293.0
#
#    Total_Spending  Days_as_Customer  Recency  Wines  ...   Fish  Sweets  Gold  \
# 0          1617.0            4861.0       58    635  ...  120.5      81  88.0
# 1            27.0            4311.0       38     11  ...    2.0       1   6.0
# 2           776.0            4510.0       26    426  ...  111.0      21  42.0
# 3            53.0            4337.0       26     11  ...   10.0       3   5.0
# 4           422.0            4359.0       94    173  ...   46.0      27  15.0
#
# ...

# %%
list_of_dict = df.to_dict(orient='records')

# %%
list_of_dict
# Out:
# [{'Age': 68,
#   'Education': 2,
#   'Marital Status': 0,
#   'Parental Status': 0,
#   'Children': 0,
#   'Income': 58138.0,
#   'Total_Spending': 1617.0,
#   'Days_as_Customer': 4861.0,
#   'Recency': 58,
#   'Wines': 635,
#   'Fruits': 81,
#   'Meat': 546,
#   'Fish': 120.5,
#   'Sweets': 81,
#   'Gold': 88.0,
#   'Web': 8,
#   'Catalog': 10,
#   'Store': 4,
#   'Discount Purchases': 3,
#   'Total Promo': 0,
#   'NumWebVisitsMonth': 7,
#   'cluster': 1},
#  {'Age': 71,
#   'Education': 2,
#   'Marital Status': 0,
#   'Parental Status': 1,
#   'Children': 2,
#   'Income': 46344.0,
#   'Total_Spending': 27.0,
#   'Days_as_Customer': 4311.0,
#   'Recency': 38,
#   'Wines': 11,
#   'Fruits': 1,
#   'Meat': 6,
#   'Fish': 2.0,
#   'Sweets': 1,
#   'Gold': 6.0,
#   'Web': 1,
#   'Catalog': 1,
#   'Store': 2,
#   'Discount Purchases': 2,
#   'Total Promo': 0,
#   'NumWebVisitsMonth': 5,
#   'cluster': 0},
#  {'Age': 60,
#   'Education': 2,
#   'Marital Status': 1,
# ...

# %%
db = client['iNeuron']

# %%
db.list_collection_names()
# Out:
# []

# %%
#create a collection
collection = db.create_collection("Customer_segmentation")

# %%
collection.insert_many(list_of_dict)
# Out:
# InsertManyResult([ObjectId('6957ff6900911aad575ca3e8'), ObjectId('6957ff6900911aad575ca3e9'), ObjectId('6957ff6900911aad575ca3ea'), ObjectId('6957ff6900911aad575ca3eb'), ObjectId('6957ff6900911aad575ca3ec'), ObjectId('6957ff6900911aad575ca3ed'), ObjectId('6957ff6900911aad575ca3ee'), ObjectId('6957ff6900911aad575ca3ef'), ObjectId('6957ff6900911aad575ca3f0'), ObjectId('6957ff6900911aad575ca3f1'), ObjectId('6957ff6900911aad575ca3f2'), ObjectId('6957ff6900911aad575ca3f3'), ObjectId('6957ff6900911aad575ca3f4'), ObjectId('6957ff6900911aad575ca3f5'), ObjectId('6957ff6900911aad575ca3f6'), ObjectId('6957ff6900911aad575ca3f7'), ObjectId('6957ff6900911aad575ca3f8'), ObjectId('6957ff6900911aad575ca3f9'), ObjectId('6957ff6900911aad575ca3fa'), ObjectId('6957ff6900911aad575ca3fb'), ObjectId('6957ff6900911aad575ca3fc'), ObjectId('6957ff6900911aad575ca3fd'), ObjectId('6957ff6900911aad575ca3fe'), ObjectId('6957ff6900911aad575ca3ff'), ObjectId('6957ff6900911aad575ca400'), ObjectId('6957ff6900911aad575c
# ...

# %%
collection.count_documents({})
# Out:
# 2240
